# %%
# Import dependencies
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read in csv files
offense_df = pd.read_csv("output/offense.csv")
defense_df = pd.read_csv("output/defense.csv")

# %%
###################################
# Offense EDA
###################################

# %%
# General Information
summary_statistic_df = offense_df.describe()

summary_statistic_df
# Out:
#        passing_cmp  passing_att  passing_pct  passing_yds  passing_td  \
# count   286.000000   286.000000   286.000000   286.000000  286.000000
# mean     15.818182    27.520979    56.932168   204.055944    1.472028
# std       7.090034    10.499687    13.020988    94.085461    1.241499
# min       2.000000     6.000000    15.400000    26.000000    0.000000
# 25%      10.250000    20.000000    48.375000   133.250000    1.000000
# 50%      16.000000    27.000000    57.500000   193.500000    1.000000
# 75%      21.000000    35.000000    65.775000   269.750000    2.000000
# max      37.000000    58.000000    92.900000   519.000000    7.000000
#
#        rushing_att  rushing_yds  rushing_avg  rushing_td  total_plays  ...  \
# count   286.000000   286.000000   286.000000  286.000000   286.000000  ...
# mean     42.744755   202.122378     4.559091    2.094406    70.265734  ...
# std      11.433771   104.822703     1.723391    1.684242     9.577716  ...
# ...

# %%
# Create a correlation heatmap
corr_matrix = offense_df.corr()

# Create a mask to filter values greater than 0.5
mask = corr_matrix > 0.5

# Create a filtered correlation matrix
filtered_corr_matrix = corr_matrix[mask]

# Create a heatmap of the filtered correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(filtered_corr_matrix, annot=True, cmap='coolwarm')
plt.show()
# Out:
# C:\Users\grant\AppData\Local\Temp\ipykernel_17836\1650876558.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = offense_df.corr()
