# %%
# Import dependencies
import pandas as pd
import numpy as np
import sqlite3

# %%
# Read in csv files
offense_df = pd.read_csv("../resources/all_offense.csv")
defense_df = pd.read_csv("../resources/all_defense.csv")

# %%
# Preview the first five rows of the offense dataset
offense_df.head()
# Out:
#    year         school  games  points  passing_cmp  passing_att  passing_pct  \
# 0  2000    Boise State   11.0    44.9         20.5         33.8         60.5
# 1  2000     Miami (FL)   11.0    42.6         18.0         30.9         58.2
# 2  2000  Florida State   12.0    42.4         24.2         39.1         61.8
# 3  2000       Nebraska   11.0    41.5          7.6         15.6         48.8
# 4  2000  Virginia Tech   11.0    40.3         10.5         20.5         51.3
#
#    passing_yds  passing_td  rushing_att  ...  total_avg  first_down_pass  \
# 0        321.5         3.4         40.0  ...        6.7             13.5
# 1        266.0         2.4         39.5  ...        6.5             12.1
# 2        384.0         3.0         37.9  ...        7.1             14.5
# 3        110.6         1.0         57.8  ...        6.3              5.2
# 4        155.9         0.8         51.8  ...        5.9              6.5
#
#    first_down_rush  first_down_pen  first_down_total  penalties  penalty_yds  \
# 0              8.9             1.5              23.9        6.2         63.5
# 1              7.7             1.4              21.2        8.8         86.5
# 2              8.0             2.8              25.3       10.2         93.9
# 3             16.8             0.9              22.9        6.5         56.5
# 4             14.7             1.2              22.5        6.4         55.7
#
#    fumbles  interceptions  turnovers
# 0      0.6            0.7        1.4
# 1      1.5            0.5        1.9
# 2      0.7            1.2        1.8
# 3      0.8            0.7        1.5
# 4      1.5            0.6        2.1
#
# [5 rows x 25 columns]

# %%
# Preview the first five rows of the defense dataset
defense_df.head()
# Out:
#    year            school  games  points  passing_cmp  passing_att  \
# 0  2000               TCU   11.0     9.6         13.0         29.4
# 1  2000     Florida State   12.0    10.3         18.3         37.3
# 2  2000            Toledo   11.0    11.4         16.4         30.7
# 3  2000  Western Michigan   12.0    11.6         14.9         28.8
# 4  2000        Miami (FL)   11.0    15.5         19.6         38.9
#
#    passing_pct  passing_yds  passing_td  rushing_att  ...  total_avg  \
# 0         44.3        160.6         0.9         35.9  ...        3.8
# 1         49.2        203.1         0.6         32.3  ...        4.0
# 2         53.3        187.5         0.5         33.2  ...        4.2
# 3         51.9        178.0         0.8         38.2  ...        4.2
# 4         50.5        220.6         1.0         35.7  ...        4.5
#
#    first_down_pass  first_down_rush  first_down_pen  first_down_total  \
# 0              6.6              5.8             2.1              14.5
# 1              9.0              4.9             2.4              16.3
# 2              8.5              5.1             0.9              14.5
# 3              7.9              6.5             1.1              15.5
# 4              9.8              6.5             2.2              18.5
#
#    penalties  penalty_yds  fumbles  interceptions  turnovers
# 0        6.4         46.8      1.1            1.4        2.5
# 1       11.1         89.4      1.1            1.6        2.7
# 2        5.5         43.3      1.5            1.4        2.8
# 3        5.7         45.4      0.8            0.8        1.5
# 4        7.5         55.4      0.9            2.1        3.0
#
# [5 rows x 25 columns]

# %%
# Inspect the information of the dataset (offense and defense should be the same)
offense_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3087 entries, 0 to 3086
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              3087 non-null   int64
#  1   school            2835 non-null   object
#  2   games             2835 non-null   float64
#  3   points            2835 non-null   float64
#  4   passing_cmp       2835 non-null   float64
#  5   passing_att       2835 non-null   float64
#  6   passing_pct       2835 non-null   float64
#  7   passing_yds       2835 non-null   float64
#  8   passing_td        2835 non-null   float64
#  9   rushing_att       2835 non-null   float64
#  10  rushing_yds       2835 non-null   float64
#  11  rushing_avg       2835 non-null   float64
#  12  rushing_td        2835 non-null   float64
#  13  total_plays       2835 non-null   float64
#  14  total_yds         2835 non-null   float64
#  15  total_avg         2835 non-null   float64
#  16  first_down_pass   2835 non-null   float64
#  17  first_down_rush   2835 non-null   float64
#  18  first_down_pen    2835 non-null   float64
#  19  first_down_total  2835 non-null   float64
#  20  penalties         2835 non-null   float64
#  21  penalty_yds       2835 non-null   float64
#  22  fumbles           2835 non-null   float64
#  23  interceptions     2835 non-null   float64
#  24  turnovers         2835 non-null   float64
# dtypes: float64(23), int64(1), object(1)
# memory usage: 603.1+ KB

# %%
# Drop rows where the year was filled in with no statistics (line break in the table)
offense_df = offense_df.dropna()
defense_df = defense_df.dropna()

# %%
# Convert the year to datetime
offense_df['year'] = pd.to_datetime(offense_df['year'], format='%Y').dt.year
defense_df['year'] = pd.to_datetime(defense_df['year'], format='%Y').dt.year

# %%
offense_df
# Out:
#       year          school  games  points  passing_cmp  passing_att  \
# 0     2000     Boise State   11.0    44.9         20.5         33.8
# 1     2000      Miami (FL)   11.0    42.6         18.0         30.9
# 2     2000   Florida State   12.0    42.4         24.2         39.1
# 3     2000        Nebraska   11.0    41.5          7.6         15.6
# 4     2000   Virginia Tech   11.0    40.3         10.5         20.5
# ...    ...             ...    ...     ...          ...          ...
# 3082  2022        Colorado   12.0    15.4         14.9         30.0
# 3083  2022    Northwestern   12.0    13.8         20.4         34.8
# 3084  2022  Colorado State   12.0    13.2         16.9         26.8
# 3085  2022      New Mexico   12.0    13.1         11.4         21.3
# 3086  2022   Massachusetts   12.0    12.5         11.3         23.1
#
#       passing_pct  passing_yds  passing_td  rushing_att  ...  total_avg  \
# 0            60.5        321.5         3.4         40.0  ...        6.7
# 1            58.2        266.0         2.4         39.5  ...        6.5
# 2            61.8        384.0         3.0         37.9  ...        7.1
# 3            48.8        110.6         1.0         57.8  ...        6.3
# 4            51.3        155.9         0.8         51.8  ...        5.9
# ...           ...          ...         ...          ...  ...        ...
# 3082         49.7        172.9         0.8         32.3  ...        4.5
# 3083         58.8        210.3         0.8         39.1  ...        4.5
# 3084         63.0        196.8         1.0         32.1  ...        4.9
# 3085         53.7        104.9         0.3         36.6  ...        3.9
# 3086         49.1        116.9         0.3         43.3  ...        4.0
#
#       first_down_pass  first_down_rush  first_down_pen  first_down_total  \
# 0                13.5              8.9             1.5              23.9
# 1                12.1              7.7             1.4              21.2
# 2                14.5              8.0             2.8              25.3
# 3                 5.2             16.8             0.9              22.9
# 4                 6.5             14.7             1.2              22.5
# ...               ...              ...             ...               ...
# 3082              7.2              7.2             1.6              15.9
# 3083              9.5              7.8             1.7              19.0
# 3084              7.9              5.5             1.3              14.7
# 3085              4.1              7.7             1.6              13.3
# 3086              5.2              7.8             1.6              14.6
#
#       penalties  penalty_yds  fumbles  interceptions  turnovers
# 0           6.2         63.5      0.6            0.7        1.4
# 1           8.8         86.5      1.5            0.5        1.9
# 2          10.2         93.9      0.7            1.2        1.8
# 3           6.5         56.5      0.8            0.7        1.5
# 4           6.4         55.7      1.5            0.6        2.1
# ...         ...          ...      ...            ...        ...
# 3082        5.3         48.3      1.0            0.8        1.8
# 3083        4.6         40.8      1.2            1.4        2.6
# 3084        6.9         60.4      0.8            0.9        1.7
# 3085        6.1         51.2      0.4            0.8        1.2
# 3086        7.6         66.7      0.5            1.2        1.7
#
# [2835 rows x 25 columns]

# %%
# Confirm that the dataset is ready for loading
offense_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2835 entries, 0 to 3086
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              2835 non-null   int64
#  1   school            2835 non-null   object
#  2   games             2835 non-null   float64
#  3   points            2835 non-null   float64
#  4   passing_cmp       2835 non-null   float64
#  5   passing_att       2835 non-null   float64
#  6   passing_pct       2835 non-null   float64
#  7   passing_yds       2835 non-null   float64
#  8   passing_td        2835 non-null   float64
#  9   rushing_att       2835 non-null   float64
#  10  rushing_yds       2835 non-null   float64
#  11  rushing_avg       2835 non-null   float64
#  12  rushing_td        2835 non-null   float64
#  13  total_plays       2835 non-null   float64
#  14  total_yds         2835 non-null   float64
#  15  total_avg         2835 non-null   float64
#  16  first_down_pass   2835 non-null   float64
#  17  first_down_rush   2835 non-null   float64
#  18  first_down_pen    2835 non-null   float64
#  19  first_down_total  2835 non-null   float64
#  20  penalties         2835 non-null   float64
#  21  penalty_yds       2835 non-null   float64
#  22  fumbles           2835 non-null   float64
#  23  interceptions     2835 non-null   float64
#  24  turnovers         2835 non-null   float64
# dtypes: float64(23), int64(1), object(1)
# memory usage: 575.9+ KB

# %%
# Confirm that the dataset is ready for loading
defense_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2835 entries, 0 to 3086
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              2835 non-null   int64
#  1   school            2835 non-null   object
#  2   games             2835 non-null   float64
#  3   points            2835 non-null   float64
#  4   passing_cmp       2835 non-null   float64
#  5   passing_att       2835 non-null   float64
#  6   passing_pct       2835 non-null   float64
#  7   passing_yds       2835 non-null   float64
#  8   passing_td        2835 non-null   float64
#  9   rushing_att       2835 non-null   float64
#  10  rushing_yds       2835 non-null   float64
#  11  rushing_avg       2835 non-null   float64
#  12  rushing_td        2835 non-null   float64
#  13  total_plays       2835 non-null   float64
#  14  total_yds         2835 non-null   float64
#  15  total_avg         2835 non-null   float64
#  16  first_down_pass   2835 non-null   float64
#  17  first_down_rush   2835 non-null   float64
#  18  first_down_pen    2835 non-null   float64
#  19  first_down_total  2835 non-null   float64
#  20  penalties         2835 non-null   float64
#  21  penalty_yds       2835 non-null   float64
#  22  fumbles           2835 non-null   float64
#  23  interceptions     2835 non-null   float64
#  24  turnovers         2835 non-null   float64
# dtypes: float64(23), int64(1), object(1)
# memory usage: 575.9+ KB

# %%
# Output the cleaned datasets to a .csv
offense_df.to_csv('../output/all_offense.csv', index=False)
defense_df.to_csv('../output/all_defense.csv', index=False)

# Connect to SQLite database
conn = sqlite3.connect('../output/cfb.db')
cursor = conn.cursor()

# Write DataFrame to SQLite database
offense_df.to_sql('all_offense', conn, if_exists='replace', index=False)
defense_df.to_sql('all_defense', conn, if_exists='replace', index=False)

# Commit changes and close the connection
conn.commit()
conn.close()
